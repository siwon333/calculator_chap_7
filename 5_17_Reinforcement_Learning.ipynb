# %% [markdown]
# <a href="https://colab.research.google.com/github/siwon333/calculator_chap_7/blob/master/5_17_Reinforcement_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib
# %matplotlib inline
import os
os.chdir('/content')

# !python Chap_12_Reinforced_Learning_Training.py
# Out:
# Using matplotlib backend: agg
# 2023-05-29 08:25:21.534288: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-29 08:25:22.648253: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-29 08:25:24.434263: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:24.467266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:24.467572: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:24.469291: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:24.469516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:24.469686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:25.474898: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:25.475229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:25.475435: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-29 08:25:25.475576: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-29 08:25:25.475631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14504 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0
# 트레이닝을 시작합니다.
# /content/Chap_12_Reinforced_Learning_Training.py:168: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
# 2023-05-29 08:25:26.076905: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x396c34a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-29 08:25:26.076952: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2023-05-29 08:25:26.254896: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8700
# 2023-05-29 08:25:26.326284: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f8cd7368310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0529 08:25:26.610815 140244928419648 polymorphic_function.py:156] 5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f8cd7368310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f8cd7368310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0529 08:25:26.691047 140244928419648 polymorphic_function.py:156] 6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f8cd7368310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 반복(Epoch): 0, 에러(err): 0.0116, 승리횟수(Win count): 1, 승리비율(Win ratio): 100.0000
# 반복(Epoch): 1, 에러(err): 0.0715, 승리횟수(Win count): 1, 승리비율(Win ratio): 50.0000
# /content/model.ckpt-1 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 2, 에러(err): 0.2037, 승리횟수(Win count): 1, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 3, 에러(err): 0.2660, 승리횟수(Win count): 2, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 4, 에러(err): 0.2529, 승리횟수(Win count): 3, 승리비율(Win ratio): 60.0000
# 반복(Epoch): 5, 에러(err): 0.3359, 승리횟수(Win count): 3, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 6, 에러(err): 0.4056, 승리횟수(Win count): 3, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 7, 에러(err): 0.4037, 승리횟수(Win count): 3, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 8, 에러(err): 0.4358, 승리횟수(Win count): 4, 승리비율(Win ratio): 44.4444
# 반복(Epoch): 9, 에러(err): 0.3660, 승리횟수(Win count): 4, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 10, 에러(err): 0.4084, 승리횟수(Win count): 5, 승리비율(Win ratio): 45.4545
# 반복(Epoch): 11, 에러(err): 0.3451, 승리횟수(Win count): 5, 승리비율(Win ratio): 41.6667
# 반복(Epoch): 12, 에러(err): 0.4023, 승리횟수(Win count): 6, 승리비율(Win ratio): 46.1538
# 반복(Epoch): 13, 에러(err): 0.4642, 승리횟수(Win count): 6, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 14, 에러(err): 0.3259, 승리횟수(Win count): 7, 승리비율(Win ratio): 46.6667
# 반복(Epoch): 15, 에러(err): 0.4314, 승리횟수(Win count): 7, 승리비율(Win ratio): 43.7500
# 반복(Epoch): 16, 에러(err): 0.3905, 승리횟수(Win count): 7, 승리비율(Win ratio): 41.1765
# 반복(Epoch): 17, 에러(err): 0.3616, 승리횟수(Win count): 7, 승리비율(Win ratio): 38.8889
# 반복(Epoch): 18, 에러(err): 0.3941, 승리횟수(Win count): 7, 승리비율(Win ratio): 36.8421
# 반복(Epoch): 19, 에러(err): 0.2664, 승리횟수(Win count): 8, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 20, 에러(err): 0.3816, 승리횟수(Win count): 8, 승리비율(Win ratio): 38.0952
# 반복(Epoch): 21, 에러(err): 0.3674, 승리횟수(Win count): 9, 승리비율(Win ratio): 40.9091
# 반복(Epoch): 22, 에러(err): 0.3473, 승리횟수(Win count): 10, 승리비율(Win ratio): 43.4783
# 반복(Epoch): 23, 에러(err): 0.3774, 승리횟수(Win count): 11, 승리비율(Win ratio): 45.8333
# 반복(Epoch): 24, 에러(err): 0.4701, 승리횟수(Win count): 11, 승리비율(Win ratio): 44.0000
# 반복(Epoch): 25, 에러(err): 0.3220, 승리횟수(Win count): 12, 승리비율(Win ratio): 46.1538
# 반복(Epoch): 26, 에러(err): 0.4999, 승리횟수(Win count): 13, 승리비율(Win ratio): 48.1481
# 반복(Epoch): 27, 에러(err): 0.3050, 승리횟수(Win count): 13, 승리비율(Win ratio): 46.4286
# 반복(Epoch): 28, 에러(err): 0.4244, 승리횟수(Win count): 13, 승리비율(Win ratio): 44.8276
# 반복(Epoch): 29, 에러(err): 0.4072, 승리횟수(Win count): 14, 승리비율(Win ratio): 46.6667
# 반복(Epoch): 30, 에러(err): 0.2475, 승리횟수(Win count): 15, 승리비율(Win ratio): 48.3871
# 반복(Epoch): 31, 에러(err): 0.3720, 승리횟수(Win count): 16, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 32, 에러(err): 0.2992, 승리횟수(Win count): 16, 승리비율(Win ratio): 48.4848
# 반복(Epoch): 33, 에러(err): 0.3201, 승리횟수(Win count): 16, 승리비율(Win ratio): 47.0588
# 반복(Epoch): 34, 에러(err): 0.3663, 승리횟수(Win count): 17, 승리비율(Win ratio): 48.5714
# 반복(Epoch): 35, 에러(err): 0.3014, 승리횟수(Win count): 17, 승리비율(Win ratio): 47.2222
# 반복(Epoch): 36, 에러(err): 0.3588, 승리횟수(Win count): 17, 승리비율(Win ratio): 45.9459
# 반복(Epoch): 37, 에러(err): 0.3002, 승리횟수(Win count): 18, 승리비율(Win ratio): 47.3684
# 반복(Epoch): 38, 에러(err): 0.4055, 승리횟수(Win count): 18, 승리비율(Win ratio): 46.1538
# 반복(Epoch): 39, 에러(err): 0.3311, 승리횟수(Win count): 18, 승리비율(Win ratio): 45.0000
# 반복(Epoch): 40, 에러(err): 0.2548, 승리횟수(Win count): 18, 승리비율(Win ratio): 43.9024
# 반복(Epoch): 41, 에러(err): 0.4769, 승리횟수(Win count): 18, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 42, 에러(err): 0.3795, 승리횟수(Win count): 18, 승리비율(Win ratio): 41.8605
# 반복(Epoch): 43, 에러(err): 0.3181, 승리횟수(Win count): 19, 승리비율(Win ratio): 43.1818
# 반복(Epoch): 44, 에러(err): 0.3610, 승리횟수(Win count): 19, 승리비율(Win ratio): 42.2222
# 반복(Epoch): 45, 에러(err): 0.3219, 승리횟수(Win count): 19, 승리비율(Win ratio): 41.3043
# 반복(Epoch): 46, 에러(err): 0.3720, 승리횟수(Win count): 20, 승리비율(Win ratio): 42.5532
# 반복(Epoch): 47, 에러(err): 0.3082, 승리횟수(Win count): 21, 승리비율(Win ratio): 43.7500
# 반복(Epoch): 48, 에러(err): 0.3752, 승리횟수(Win count): 21, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 49, 에러(err): 0.3537, 승리횟수(Win count): 21, 승리비율(Win ratio): 42.0000
# 반복(Epoch): 50, 에러(err): 0.3845, 승리횟수(Win count): 21, 승리비율(Win ratio): 41.1765
# 반복(Epoch): 51, 에러(err): 0.3865, 승리횟수(Win count): 22, 승리비율(Win ratio): 42.3077
# 반복(Epoch): 52, 에러(err): 0.3235, 승리횟수(Win count): 22, 승리비율(Win ratio): 41.5094
# 반복(Epoch): 53, 에러(err): 0.2722, 승리횟수(Win count): 22, 승리비율(Win ratio): 40.7407
# 반복(Epoch): 54, 에러(err): 0.2956, 승리횟수(Win count): 22, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 55, 에러(err): 0.2765, 승리횟수(Win count): 22, 승리비율(Win ratio): 39.2857
# 반복(Epoch): 56, 에러(err): 0.2390, 승리횟수(Win count): 23, 승리비율(Win ratio): 40.3509
# 반복(Epoch): 57, 에러(err): 0.2774, 승리횟수(Win count): 23, 승리비율(Win ratio): 39.6552
# 반복(Epoch): 58, 에러(err): 0.3234, 승리횟수(Win count): 23, 승리비율(Win ratio): 38.9831
# 반복(Epoch): 59, 에러(err): 0.2777, 승리횟수(Win count): 23, 승리비율(Win ratio): 38.3333
# 반복(Epoch): 60, 에러(err): 0.3189, 승리횟수(Win count): 23, 승리비율(Win ratio): 37.7049
# 반복(Epoch): 61, 에러(err): 0.3368, 승리횟수(Win count): 24, 승리비율(Win ratio): 38.7097
# 반복(Epoch): 62, 에러(err): 0.3172, 승리횟수(Win count): 24, 승리비율(Win ratio): 38.0952
# 반복(Epoch): 63, 에러(err): 0.2716, 승리횟수(Win count): 24, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 64, 에러(err): 0.3864, 승리횟수(Win count): 25, 승리비율(Win ratio): 38.4615
# 반복(Epoch): 65, 에러(err): 0.3226, 승리횟수(Win count): 25, 승리비율(Win ratio): 37.8788
# 반복(Epoch): 66, 에러(err): 0.3281, 승리횟수(Win count): 26, 승리비율(Win ratio): 38.8060
# 반복(Epoch): 67, 에러(err): 0.3545, 승리횟수(Win count): 26, 승리비율(Win ratio): 38.2353
# 반복(Epoch): 68, 에러(err): 0.3286, 승리횟수(Win count): 27, 승리비율(Win ratio): 39.1304
# 반복(Epoch): 69, 에러(err): 0.3294, 승리횟수(Win count): 27, 승리비율(Win ratio): 38.5714
# 반복(Epoch): 70, 에러(err): 0.2559, 승리횟수(Win count): 27, 승리비율(Win ratio): 38.0282
# 반복(Epoch): 71, 에러(err): 0.2948, 승리횟수(Win count): 27, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 72, 에러(err): 0.2912, 승리횟수(Win count): 27, 승리비율(Win ratio): 36.9863
# 반복(Epoch): 73, 에러(err): 0.2926, 승리횟수(Win count): 27, 승리비율(Win ratio): 36.4865
# 반복(Epoch): 74, 에러(err): 0.3020, 승리횟수(Win count): 27, 승리비율(Win ratio): 36.0000
# 반복(Epoch): 75, 에러(err): 0.2594, 승리횟수(Win count): 28, 승리비율(Win ratio): 36.8421
# 반복(Epoch): 76, 에러(err): 0.2370, 승리횟수(Win count): 29, 승리비율(Win ratio): 37.6623
# 반복(Epoch): 77, 에러(err): 0.2947, 승리횟수(Win count): 29, 승리비율(Win ratio): 37.1795
# 반복(Epoch): 78, 에러(err): 0.3011, 승리횟수(Win count): 29, 승리비율(Win ratio): 36.7089
# 반복(Epoch): 79, 에러(err): 0.2557, 승리횟수(Win count): 29, 승리비율(Win ratio): 36.2500
# 반복(Epoch): 80, 에러(err): 0.3322, 승리횟수(Win count): 30, 승리비율(Win ratio): 37.0370
# 반복(Epoch): 81, 에러(err): 0.3817, 승리횟수(Win count): 31, 승리비율(Win ratio): 37.8049
# 반복(Epoch): 82, 에러(err): 0.3133, 승리횟수(Win count): 31, 승리비율(Win ratio): 37.3494
# 반복(Epoch): 83, 에러(err): 0.3200, 승리횟수(Win count): 31, 승리비율(Win ratio): 36.9048
# 반복(Epoch): 84, 에러(err): 0.2844, 승리횟수(Win count): 32, 승리비율(Win ratio): 37.6471
# 반복(Epoch): 85, 에러(err): 0.3312, 승리횟수(Win count): 32, 승리비율(Win ratio): 37.2093
# 반복(Epoch): 86, 에러(err): 0.2526, 승리횟수(Win count): 33, 승리비율(Win ratio): 37.9310
# 반복(Epoch): 87, 에러(err): 0.2589, 승리횟수(Win count): 34, 승리비율(Win ratio): 38.6364
# 반복(Epoch): 88, 에러(err): 0.2081, 승리횟수(Win count): 35, 승리비율(Win ratio): 39.3258
# 반복(Epoch): 89, 에러(err): 0.2957, 승리횟수(Win count): 36, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 90, 에러(err): 0.2825, 승리횟수(Win count): 37, 승리비율(Win ratio): 40.6593
# 반복(Epoch): 91, 에러(err): 0.3310, 승리횟수(Win count): 37, 승리비율(Win ratio): 40.2174
# 반복(Epoch): 92, 에러(err): 0.3052, 승리횟수(Win count): 37, 승리비율(Win ratio): 39.7849
# 반복(Epoch): 93, 에러(err): 0.2893, 승리횟수(Win count): 38, 승리비율(Win ratio): 40.4255
# 반복(Epoch): 94, 에러(err): 0.2334, 승리횟수(Win count): 39, 승리비율(Win ratio): 41.0526
# 반복(Epoch): 95, 에러(err): 0.1975, 승리횟수(Win count): 39, 승리비율(Win ratio): 40.6250
# 반복(Epoch): 96, 에러(err): 0.2406, 승리횟수(Win count): 40, 승리비율(Win ratio): 41.2371
# 반복(Epoch): 97, 에러(err): 0.2425, 승리횟수(Win count): 40, 승리비율(Win ratio): 40.8163
# 반복(Epoch): 98, 에러(err): 0.2015, 승리횟수(Win count): 40, 승리비율(Win ratio): 40.4040
# 반복(Epoch): 99, 에러(err): 0.2136, 승리횟수(Win count): 40, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 100, 에러(err): 0.1794, 승리횟수(Win count): 41, 승리비율(Win ratio): 40.5941
# 트레이닝 완료
# /content/model.ckpt-100 경로에 파라미터가 저장되었습니다

# %%
from Chap_12_Reinforced_Learning_Training import CatchEnvironment, DQN
from IPython import display
import matplotlib.patches as patches
import pylab as pl
import time
import tensorflow as tf
import os

# %%
# 설정값들을 정의합니다.
gridSize = 10
maxGames = 30
DQN_model = DQN()
env = CatchEnvironment(gridSize)
winCount = 0
loseCount = 0
numberOfGames = 0

# %%
# 현재 상태를 그리기 위한 drawState 함수를 정의합니다.
def drawState(fruitRow, fruitColumn, basket, gridSize):
  # 과일이 몇번째 세로축에 있는지 정의합니다.
  fruitX = fruitColumn 
  # 과일이 몇번째 가로축에 있는지 정의합니다.
  fruitY = (gridSize - fruitRow + 1)
  # 승리 횟수, 패배 횟수, 전체 게임 횟수를 화면 상단에 출력합니다.
  statusTitle = "Wins: " + str(winCount) + "  Losses: " + str(loseCount) + "  TotalGame: " + str(numberOfGames)
  axis.set_title(statusTitle, fontsize=30)
  for p in [
    # 배경의 위치를 지정합니다.
    patches.Rectangle(
        ((ground - 1), (ground)), 11, 10,
        facecolor="#000000"      # Black
    ),
    # 바구니의 위치를 지정합니다.
    patches.Rectangle(
        (basket - 1, ground), 2, 0.5,
        facecolor="#FF0000"     # Red
    ),
    # 과일의 위치를 지정합니다.
    patches.Rectangle(
        (fruitX - 0.5, fruitY - 0.5), 1, 1,
        facecolor="#0000FF"       # Blue
    ),   
    ]:
      axis.add_patch(p)
  display.clear_output(wait=True)
  display.display(pl.gcf())

# %%
# 저장된 파라미터를 불러옵니다.
ckpt = tf.train.Checkpoint(model=DQN_model)
latest_ckpt = '/content/model.ckpt-100'

ckpt.restore(latest_ckpt)

print('저장된 파라미터를 불러왔습니다!')
# Out:
# 저장된 파라미터를 불러왔습니다!

# %%
# GIF를 만들기위해 설치합니다.
# !pip install imageio

# !mkdir '/content/generated_output/'

import glob
import imageio
import matplotlib.pyplot as plt
import PIL

def display_image(epoch_no):
  return PIL.Image.open('/content/generated_output/image_at_epoch_{:04d}.png'.format(epoch_no))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.22.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (8.4.0)
# mkdir: cannot create directory ‘/content/generated_output/’: File exists

# %%
# 화면을 그리기 위한 설정들을 정의합니다.
ground = 1
plot = pl.figure(figsize=(12,12))
axis = plot.add_subplot(111, aspect='equal')
axis.set_xlim([-1, 12])
axis.set_ylim([0, 12])

frame = 1

# maxGames 횟수만큼 게임을 플레이합니다.
while (numberOfGames < maxGames):
  numberOfGames = numberOfGames + 1

  # 최초의 상태를 정의합니다.
  isGameOver = False
  fruitRow, fruitColumn, basket = env.reset()
  currentState = env.observe()
  drawState(fruitRow, fruitColumn, basket, gridSize)

  while (isGameOver != True):
    # 현재 상태를 DQN의 입력값으로 넣고 구한 Q값중 가장 큰 Q값을 갖는 행동을 취합니다.
    q = DQN_model(currentState).numpy()
    action = q.argmax()

    # 행동을 취하고 다음 상태로 넘어갑니다.
    nextState, reward, gameOver, stateInfo = env.act(action)    
    fruitRow = stateInfo[0]
    fruitColumn = stateInfo[1]
    basket = stateInfo[2]
     
    # 과일을 받아내면 winCount를 1 늘리고 과일을 받아내지 못하면 loseCount를 1 늘립니다.
    if (reward == 1):
      winCount = winCount + 1
    elif (reward == -1):
      loseCount = loseCount + 1

    currentState = nextState
    isGameOver = gameOver
    drawState(fruitRow, fruitColumn, basket, gridSize)
    # 다음 행동을 취하기 전에 0.05초의 일시정지를 줍니다.
#    time.sleep(5)
    plt.savefig('/content/generated_output/image_at_frame_{:04d}.png'.format(frame))
    frame = frame+1

# 최종 출력결과 이미지를 하나로 정리합니다.
display.clear_output(wait=True)

# %%
anim_file = '/content/generated_output/dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('/content/generated_output/image*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

import IPython
if IPython.version_info > (6,2,0,''):
  display.Image(filename=anim_file)
# Out:
# <ipython-input-12-b2b7cd20ce6a>:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# <ipython-input-12-b2b7cd20ce6a>:15: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)

# %%
from google.colab import files

files.download(anim_file)
# !zip -r /content/file.zip /content/generated_output
files.download("/content/file.zip")
# Out:
#   adding: content/generated_output/ (stored 0%)
#   adding: content/generated_output/image_at_frame_0028.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0015.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0031.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0119.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0036.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0129.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0140.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0027.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0131.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0122.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0042.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0096.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0056.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0072.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0159.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0083.png (deflated 38%)
#   adding: content/generated_output/image_at_frame_0136.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0022.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0176.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0059.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0150.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0182.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0203.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0126.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0013.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0127.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0046.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0222.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0064.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0133.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0227.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0039.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0197.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0071.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0125.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0100.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0043.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0113.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0214.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0169.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0107.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0102.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0137.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0199.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0196.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0079.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0151.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0110.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0141.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0193.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0051.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0115.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0097.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0121.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0158.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0058.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0234.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0063.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0215.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0016.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0228.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0106.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0204.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0194.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0239.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0200.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0026.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0218.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0099.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0108.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0098.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0095.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0070.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0237.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0225.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0224.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0065.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0212.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0233.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0105.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0005.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0220.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0112.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0103.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0139.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0080.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0060.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0135.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0068.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0117.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0094.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0062.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0145.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0053.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0057.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0154.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0198.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0008.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0104.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0138.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0033.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0124.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0206.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0157.png (deflated 36%)
#   adding: content/generated_output/dcgan.gif (deflated 19%)
#   adding: content/generated_output/image_at_frame_0073.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0003.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0032.png (deflated 38%)
#   adding: content/generated_output/image_at_frame_0086.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0077.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0238.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0168.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0209.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0210.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0055.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0052.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0226.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0240.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0221.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0084.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0164.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0144.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0236.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0123.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0090.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0017.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0189.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0167.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0006.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0175.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0061.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0170.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0002.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0029.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0166.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0091.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0012.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0174.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0118.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0035.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0007.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0190.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0128.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0038.png (deflated 38%)
#   adding: content/generated_output/image_at_frame_0087.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0069.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0066.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0161.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0019.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0089.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0185.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0049.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0179.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0192.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0030.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0186.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0134.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0082.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0074.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0231.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0054.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0172.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0230.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0149.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0208.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0232.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0147.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0184.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0207.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0171.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0010.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0195.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0034.png (deflated 38%)
#   adding: content/generated_output/image_at_frame_0114.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0085.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0021.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0111.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0088.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0024.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0045.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0130.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0146.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0025.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0116.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0076.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0092.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0213.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0219.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0040.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0009.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0120.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0177.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0183.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0148.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0109.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0143.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0229.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0037.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0018.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0235.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0201.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0078.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0023.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0142.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0191.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0075.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0001.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0047.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0205.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0156.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0020.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0093.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0067.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0180.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0160.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0101.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0163.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0165.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0041.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0202.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0211.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0153.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0014.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0152.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0181.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0011.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0155.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0081.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0004.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0048.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0050.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0188.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0187.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0162.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0178.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0223.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0044.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0217.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0173.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0216.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0132.png (deflated 37%)
